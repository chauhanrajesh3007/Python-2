# %% [markdown]
# # rest API(representational state transfer application programming interface)

# %%
import requests,json
city=input("enter city:")
api_key="81c148fded66cf6945b9fe227e878f6e"
url="http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_key
response=requests.get(url)
result=response.json()
print(result)
print(json.dumps(result,indent=3))
# Out:
# enter city:pune
# [{'name': 'Pune', 'local_names': {'hi': 'पुणे', 'ur': 'شہر پونے', 'el': 'Πούνε', 'bg': 'Пуна', 'ml': 'പൂണെ', 'pa': 'ਪੁਣੇ', 'ps': 'پونی', 'be': 'Пуна', 'fa': 'پونه', 'he': 'פונה', 'de': 'Pune', 'te': 'పూణే', 'fr': 'Pune', 'ar': 'مدينة بونه', 'ne': 'पुणे', 'az': 'Puna', 'en': 'Pune', 'ru': 'Пуне', 'bn': 'পুনে', 'hu': 'Púne', 'sr': 'Пуне', 'uk': 'Пуне', 'mr': 'पुणे शहर', 'sl': 'Pune', 'hr': 'Pune', 'kn': 'ಪುಣೆ', 'zh': '浦那'}, 'lat': 18.5213738, 'lon': 73.8545071, 'country': 'IN', 'state': 'Maharashtra'}]
# [
#    {
#       "name": "Pune",
#       "local_names": {
#          "hi": "\u092a\u0941\u0923\u0947",
#          "ur": "\u0634\u06c1\u0631 \u067e\u0648\u0646\u06d2",
#          "el": "\u03a0\u03bf\u03cd\u03bd\u03b5",
#          "bg": "\u041f\u0443\u043d\u0430",
#          "ml": "\u0d2a\u0d42\u0d23\u0d46",
#          "pa": "\u0a2a\u0a41\u0a23\u0a47",
#          "ps": "\u067e\u0648\u0646\u06cc",
#          "be": "\u041f\u0443\u043d\u0430",
# ...

# %%
lat=result[0]["lat"]
print(lat)
# Out:
# 18.5213738

# %%
lon=result[0]["lon"]
print(lon)
# Out:
# 73.8545071

# %%
url1="https://api.openweathermap.org/data/2.5/weather?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key+"&units=metric"
response=requests.get(url1)
result=response.json()
print(result)
print(json.dumps(result,indent=3))
# Out:
# {'coord': {'lon': 73.8545, 'lat': 18.5214}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 30.78, 'feels_like': 31.07, 'temp_min': 30.78, 'temp_max': 30.78, 'pressure': 1012, 'humidity': 43, 'sea_level': 1012, 'grnd_level': 940}, 'visibility': 10000, 'wind': {'speed': 4.28, 'deg': 278, 'gust': 4.48}, 'clouds': {'all': 4}, 'dt': 1779856240, 'sys': {'type': 2, 'id': 2104163, 'country': 'IN', 'sunrise': 1779841688, 'sunset': 1779888936}, 'timezone': 19800, 'id': 1259229, 'name': 'Pune', 'cod': 200}
# {
#    "coord": {
#       "lon": 73.8545,
#       "lat": 18.5214
#    },
#    "weather": [
#       {
#          "id": 800,
#          "main": "Clear",
#          "description": "clear sky",
#          "icon": "01d"
#       }
#    ],
#    "base": "stations",
#    "main": {
#       "temp": 30.78,
#       "feels_like": 31.07,
#       "temp_min": 30.78,
#       "temp_max": 30.78,
#       "pressure": 1012,
# ...

# %%
temp=result["main"]["temp"]
print(temp)
# Out:
# 30.78

# %%
wind_speed=result["wind"]["speed"]
print(wind_speed)
# Out:
# 4.28

# %%
weather_description=result["weather"][0]["description"]
print(weather_description)
# Out:
# clear sky

# %%
url2="http://api.openweathermap.org/data/2.5/air_pollution?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key
response=requests.get(url2)
result=response.json()
print(result)
print(json.dumps(result,indent=3))
# Out:
# {'coord': {'lon': 73.8545, 'lat': 18.5214}, 'list': [{'main': {'aqi': 1}, 'components': {'co': 86.2, 'no': 0.15, 'no2': 0.45, 'o3': 29.15, 'so2': 0.42, 'pm2_5': 0.77, 'pm10': 1.68, 'nh3': 1.51}, 'dt': 1779856645}]}
# {
#    "coord": {
#       "lon": 73.8545,
#       "lat": 18.5214
#    },
#    "list": [
#       {
#          "main": {
#             "aqi": 1
#          },
#          "components": {
#             "co": 86.2,
#             "no": 0.15,
#             "no2": 0.45,
#             "o3": 29.15,
#             "so2": 0.42,
#             "pm2_5": 0.77,
#             "pm10": 1.68,
#             "nh3": 1.51
#          },
#          "dt": 1779856645
#       }
#    ]
# }

# %%
aqi=result["list"][0]["main"]["aqi"]
print(aqi)
# Out:
# 1

# %%
url3="http://api.openweathermap.org/data/2.5/forecast?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key+"&units=metric"
response=requests.get(url3)
result=response.json()
# print(result)
print(json.dumps(result,indent=3))
date_time=[]
temp=[]
weather=[]
# Out:
# {
#    "cod": "200",
#    "message": 0,
#    "cnt": 40,
#    "list": [
#       {
#          "dt": 1779861600,
#          "main": {
#             "temp": 30.78,
#             "feels_like": 31.07,
#             "temp_min": 30.78,
#             "temp_max": 33.77,
#             "pressure": 1011,
#             "sea_level": 1011,
#             "grnd_level": 940,
#             "humidity": 43,
#             "temp_kf": -2.99
#          },
#          "weather": [
#             {
#                "id": 800,
#                "main": "Clear",
#                "description": "clear sky",
#                "icon": "01d"
#             }
#          ],
#          "clouds": {
#             "all": 5
#          },
#          "wind": {
#             "speed": 4.07,
#             "deg": 285,
#             "gust": 3.76
#          },
#          "visibility": 10000,
#          "pop": 0,
#          "sys": {
#             "pod": "d"
#          },
#          "dt_txt": "2026-05-27 06:00:00"
#       },
#       {
# ...

# %%
for i in result["list"]:
    date_time.append(i["dt_txt"])
    temp.append(i["main"]["temp"])
    weather.append(i["weather"][0]["description"])
import pandas as pd
df=pd.DataFrame({"date":date_time,"temp":temp,"weather":weather})
df
# Out:
#                    date   temp           weather
# 0   2026-05-27 06:00:00  30.78         clear sky
# 1   2026-05-27 09:00:00  32.76        few clouds
# 2   2026-05-27 12:00:00  34.15        few clouds
# 3   2026-05-27 15:00:00  30.36         clear sky
# 4   2026-05-27 18:00:00  27.59         clear sky
# 5   2026-05-27 21:00:00  25.54         clear sky
# 6   2026-05-28 00:00:00  24.23         clear sky
# 7   2026-05-28 03:00:00  27.42         clear sky
# 8   2026-05-28 06:00:00  33.82         clear sky
# 9   2026-05-28 09:00:00  36.66         clear sky
# 10  2026-05-28 12:00:00  34.91         clear sky
# 11  2026-05-28 15:00:00  29.31         clear sky
# 12  2026-05-28 18:00:00  26.26         clear sky
# 13  2026-05-28 21:00:00  24.70         clear sky
# 14  2026-05-29 00:00:00  24.27         clear sky
# 15  2026-05-29 03:00:00  27.82         clear sky
# 16  2026-05-29 06:00:00  33.38         clear sky
# 17  2026-05-29 09:00:00  35.87         clear sky
# ...

# %%
import requests,json
url="https://jsonplaceholder.typicode.com/posts/1"
response=requests.get(url)
print(response)
print(response.status_code)
print(response.text)
data=response.json()
print(type(data))
print(data["userId"])
print(data["title"])
print("---"*40)
print("pretty print json")
print(json.dumps(data,indent=4))
# Out:
# <Response [200]>
# 200
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }
# <class 'dict'>
# 1
# sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# ------------------------------------------------------------------------------------------------------------------------
# pretty print json
# {
#     "userId": 1,
#     "id": 1,
#     "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#     "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %%
url="https://jsonplaceholder.typicode.com/posts"
r=requests.get(url)
data=r.json()
for i in data[:5]:
    print(i["id"],"---",i["title"],)
# Out:
# 1 --- sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# 2 --- qui est esse
# 3 --- ea molestias quasi exercitationem repellat qui ipsa sit aut
# 4 --- eum et est occaecati
# 5 --- nesciunt quas odio

# %%
#send query parameter
params={"userId":1}
r=requests.get("https://jsonplaceholder.typicode.com/posts",params=params)
print(r.url)
filtered_post=r.json()
print(filtered_post)
print("---"*40)

# Send custom headers
headers = {
"User-Agent": "Mozilla/5.0",
"Accept": "application/json"
}
response = requests.get(
"https://jsonplaceholder.typicode.com/posts/1",
headers=headers
)
print(response.status_code)
print("---"*40)

# Send POST request
new_post = {
"title": "Learning Requests",
"body": "This is tutorial content",
"userId": 1
}
response = requests.post(
"https://jsonplaceholder.typicode.com/posts",
json=new_post
)
print(response.status_code)
print(response.json())
print("---"*40)

# Send PUT request
updated_post = {
"id": 1,
"title": "Updated Title",
"body": "Updated body",
"userId": 1
}
response = requests.put(
"https://jsonplaceholder.typicode.com/posts/1",
json=updated_post
)
print(response.json())
print("---"*40)

# Send PATCH request
patch_data = {"title": "Patched Title"}
response = requests.patch("https://jsonplaceholder.typicode.com/posts/1",json=patch_data)
print(response.json())
print("---"*40)

# Send DELETE request
response = requests.delete("https://jsonplaceholder.typicode.com/posts/1")
print(response.status_code)
# Out:
# https://jsonplaceholder.typicode.com/posts?userId=1
# ...

# %%
import pandas as pd
# View response headers
response = requests.get(
"https://jsonplaceholder.typicode.com/posts/1"
)
print(response.headers)
print("---"*40)
# Check content type
print(response.headers["Content-Type"])
print("---"*40)
# Download image using binary content
image_url = "https://picsum.photos/200"
response = requests.get(image_url)
with open("random_image.jpg", "wb") as f:
    f.write(response.content)
print("Image downloaded")
print("---"*40)
# Save JSON data to file
response = requests.get(
"https://jsonplaceholder.typicode.com/posts/1"
)
data = response.json()
with open("post.json", "w") as f:
    json.dump(data, f, indent=4)
print("JSON file saved")
print("---"*40)
# Read JSON data from file
with open("post.json", "r") as f:
    loaded_data = json.load(f)
print(loaded_data)
print("---"*40)
# Convert API response to DataFrame
response = requests.get(
"https://jsonplaceholder.typicode.com/posts"
)
posts = response.json()
df = pd.DataFrame(posts)
print(df.head())
print("---"*40)
# Loop through API data
for post in posts[:5]:
    print("ID:", post["id"])
    print("TITLE:", post["title"])
    print("BODY:", post["body"])
    print("-" * 50)
# Out:
# {'Date': 'Sat, 30 May 2026 03:43:14 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Credentials': 'true', 'Cache-Control': 'max-age=43200', 'Etag': 'W/"124-yiKdLzqO5gfBrJFrcdJ8Yq0LGnU"', 'Expires': '-1', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Pragma': 'no-cache', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=QglcSgAbDGSgTVeC%2FTtt2BgLQcIUu2Sziv5yPbSe4iM%3D\\u0026sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d\\u0026ts=1772037115"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=QglcSgAbDGSgTVeC%2FTtt2BgLQcIUu2Sziv5yPbSe4iM%3D&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&ts=1772037115"', 'Server': 'cloudflare', 'Vary': 'Origin, Accept-Encoding', 'Via': '2.0 heroku-router', 'X-Content-Type-Options': 'nosniff', 'X-Powered-By': 'Express', '
# ...

# %%
url="https://jsonplaceholder.typicode.com/users/1"
# for given url grt json and find name,email,city  and company name
response = requests.get(url)
user = response.json()
print(user)
# Access nested JSON values
print(user["name"])
print(user["email"])
print(user["address"]["city"])
print(user["company"]["name"])
# Out:
# {'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}
# Leanne Graham
# Sincere@april.biz
# Gwenborough
# Romaguera-Crona

# %%
# Convert JSON string into Python object
json_string = '''
{
"name": "Alice",
"age": 25
}
'''
python_data = json.loads(json_string)
print(python_data)
print(type(python_data))
# Out:
# {'name': 'Alice', 'age': 25}
# <class 'dict'>

# %%
# Convert Python object into JSON string
person = {
"name": "Bob",
"age": 30
}
json_output = json.dumps(person, indent=4)
print(json_output)
# Out:
# {
#     "name": "Bob",
#     "age": 30
# }

# %%
# Show common HTTP status codes
print("200 = OK")
print("201 = Created")
print("400 = Bad Request")
print("401 = Unauthorized")
print("403 = Forbidden")
print("404 = Not Found")
print("500 = Server Error")
# Out:
# 200 = OK
# 201 = Created
# 400 = Bad Request
# 401 = Unauthorized
# 403 = Forbidden
# 404 = Not Found
# 500 = Server Error

# %%
#pagination
url="https://jsonplaceholder.typicode.com/posts"
params={"_page":1,"_limit":5}

r=requests.get(url,params=params)
data=r.json()
# print(data)
for i in data:
    print(i["id"],"---",i["title"])
# Out:
# 1 --- sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# 2 --- qui est esse
# 3 --- ea molestias quasi exercitationem repellat qui ipsa sit aut
# 4 --- eum et est occaecati
# 5 --- nesciunt quas odio

# %%
#multiple pagination
import requests,json
url="https://jsonplaceholder.typicode.com/posts"
page=1
while page<=3:
    params={"_page":page,"_limit":5}
    
    r=requests.get(url,params=params)
    data=r.json()
    print(f"\npage {page}")
    for i in data:
        print(i["id"],"---",i["title"])
    page+=1
# Out:
# page 1
# 1 --- sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# 2 --- qui est esse
# 3 --- ea molestias quasi exercitationem repellat qui ipsa sit aut
# 4 --- eum et est occaecati
# 5 --- nesciunt quas odio
#
# page 2
# 6 --- dolorem eum magni eos aperiam quia
# 7 --- magnam facilis autem
# 8 --- dolorem dolore est ipsam
# 9 --- nesciunt iure omnis dolorem tempora et accusantium
# 10 --- optio molestias id quia eum
#
# page 3
# 11 --- et ea vero quia laudantium autem
# 12 --- in quibusdam tempore odit est dolorem
# 13 --- dolorum ut in voluptas mollitia et saepe quo animi
# 14 --- voluptatem eligendi optio
# 15 --- eveniet quod temporibus

# %%
r=requests.get("https://api.github.com/rate_limit")
data=r.json()
print("limits=",data["rate"]["limit"])
print("remaining=",data["rate"]["remaining"])
# Out:
# limits= 60
# remaining= 0

# %%
for i in range(70):
    r=requests.get("https://api.github.com/users/octocat")
    print(i+1,r.status_code)
    if r.status_code==403:
        data=r.json()
        if"API rate limit exceeded" in data.get("message",""):
            print("rate limit exceeded")
            print(data["message"])
            break
# Out:
# 1 403
# rate limit exceeded
# API rate limit exceeded for 120.72.91.122. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
